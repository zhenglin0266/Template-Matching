# %%
import numpy as np
from scipy import signal
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import random

plt.rcParams['figure.figsize'] = (10.5, 3)

plt.subplot(1,4,1)
score = []
with open("Template C_normal1_square_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]

score1 = []
with open("Poisson Approximate_C-normal-square.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))

plt.hist(score, alpha=0.7,normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Squared error') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.subplot(1,4,2)
score = []
with open("Template C_normal1_abs_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]

score1 = []
with open("Poisson Approximate_C-normal-abs.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
        
plt.hist(score, alpha=0.7,normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Absolute-value')  
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.subplot(1,4,3)
score = []
with open("Template C_normal1_huber_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]

score1 = []
with open("Poisson Approximate_C-normal-huber.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
        
plt.hist(score,alpha=0.7, normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Huber') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.subplot(1,4,4)
score = []
with open("Template C_normal1_tukey_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]

score1 = []
with open("Poisson Approximate_C-normal-tukey.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
        
plt.hist(score, alpha=0.7, normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Tukey') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.tight_layout()
plt.show()

# %%
plt.rcParams['figure.figsize'] = (10.5, 3)


plt.subplot(1,3,1)
score = []
with open("Template C_cauchy1_abs_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]
score1 = []
with open("Poisson Approximate_C-cauchy-abs.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
plt.hist(score,alpha=0.7, normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Absolute-value')  
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.subplot(1,3,2)
score = []
with open("Template C_cauchy1_huber_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]
score1 = []
with open("Poisson Approximate_C-cauchy-huber.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
plt.hist(score,alpha=0.7, normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Huber') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.subplot(1,3,3)
score = []
with open("Template C_cauchy1_tukey_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]
score1 = []
with open("Poisson Approximate_C-cauchy-tukey.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
plt.hist(score,alpha=0.7, normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Tukey') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.tight_layout()
plt.show()

# %%
import numpy as np
from scipy import signal
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import random

plt.rcParams['figure.figsize'] = (10.5, 3)

plt.subplot(1,4,1)
score = []
with open("Template C_t3_square_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]

score1 = []
with open("Poisson Approximate_C-t3-square.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))

plt.hist(score, alpha=0.7,normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Squared error') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.subplot(1,4,2)
score = []
with open("Template C_t3_abs_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]

score1 = []
with open("Poisson Approximate_C-t3-abs.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
        
plt.hist(score, alpha=0.7,normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Absolute-value')  
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.subplot(1,4,3)
score = []
with open("Template C_t3_huber_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]

score1 = []
with open("Poisson Approximate_C-t3-huber.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
        
plt.hist(score,alpha=0.7, normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Huber') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.subplot(1,4,4)
score = []
with open("Template C_t3_tukey_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]

score1 = []
with open("Poisson Approximate_C-t3-tukey.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
        
plt.hist(score, alpha=0.7, normed =1)
plt.hist(score1, alpha=0.6,normed =1)
plt.title('Tukey') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.ylabel('Probability density') 

plt.tight_layout()
plt.show()

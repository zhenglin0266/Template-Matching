# %%
import numpy as np
from scipy import signal
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import random
import scipy.stats as stats
import matplotlib.mlab as mlab 
import matplotlib.gridspec as gridspec 
import math

gs = gridspec.GridSpec(4, 6)
plt.rcParams['figure.figsize'] = (10.5, 6)

plt.subplot(gs[:2,:2])

score = []
with open("Template E_t3_abs_100_1000.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*100 for i in score]        
score1 = []
with open("Poisson Approximate_E-t3-abs.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
plt.hist(score,bins=30,alpha=0.7, normed =1)
plt.hist(score1,bins=30, alpha=0.6,normed =1)

plt.ylabel('Probability density') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.title('n=100') 

plt.subplot(gs[:2,2:4])

score = []
with open("Template E_t3_abs_500_1000.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*500 for i in score]        
score1 = []
with open("Poisson Approximate_E-t3-abs.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
plt.hist(score,bins=30,alpha=0.7, normed =1)
plt.hist(score1,bins=30, alpha=0.6,normed =1)

plt.ylabel('Probability density') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.title('n=500') 


plt.subplot(gs[:2,4:6])

score = []
with open("Template E_t3_abs_1000_1000.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*1000 for i in score]        
score1 = []
with open("Poisson Approximate_E-t3-abs.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
plt.hist(score,bins=30,alpha=0.7, normed =1)
plt.hist(score1,bins=30, alpha=0.6,normed =1)
plt.ylabel('Probability density') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.title('n=1000')  

plt.subplot(gs[2:, 1:3])

score = []
with open("Template E_t3_abs_5000_1000.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*5000 for i in score]        
score1 = []
with open("Poisson Approximate_E-t3-abs.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
plt.hist(score,bins=30,alpha=0.7, normed =1)
plt.hist(score1, bins=30,alpha=0.6,normed =1)
 
plt.ylabel('Probability density')
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.title('n=5000') 

plt.subplot(gs[2:, 3:5])

score = []
with open("Template E_t3_abs_10000_1000.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]        
score1 = []
with open("Poisson Approximate_E-t3-abs.txt", "r") as f:
    for line in f:
        score1.append(float(line.strip()))
plt.hist(score,bins=30,alpha=0.7, normed =1)
plt.hist(score1, bins=30,alpha=0.6,normed =1)

plt.ylabel('Probability density') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.title('n=10000') 

plt.tight_layout()
plt.show()

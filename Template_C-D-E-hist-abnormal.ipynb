# %%
import numpy as np
from scipy import signal
import pandas as pd
import datetime
from matplotlib import pyplot as plt
import random
import scipy.stats as stats
import matplotlib.mlab as mlab 
import math


plt.rcParams['figure.figsize'] = (13, 3)

plt.subplot(1,3,1)

score = []
with open("Template C_cauchy1_square_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]        
plt.hist(score, normed =1)
plt.ylabel('Probability density') 
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.title('Filter C in Cauchy noise (Squared error)')  

plt.subplot(1,3,2)

score = []
with open("Template D_cauchy1_square_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]        
plt.hist(score, normed =1) 
plt.ylabel('Probability density')
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.title('Filter D in Cauchy noise (Squared error)') 

plt.subplot(1,3,3)

score = []
with open("Template E_cauchy1_square_10000_200.txt", "r") as f:
    for line in f:
        score.append(float(line.strip()))
score = [i*10000 for i in score]        
plt.hist(score, normed =1) 
plt.ylabel('Probability density')
plt.xlabel(r'$n(\hat{\theta_n}-\theta^*$)',fontsize =11) 
plt.title('Filter E in Cauchy noise (Squared error)') 

plt.tight_layout()
plt.show()
